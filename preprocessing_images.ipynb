# %%
# import the necessary packages
from utils.remove_crop_background import remove_crop_background

# %%
# remove background and crop images from dataset_kopra_splitted/train and save to dataset_kopra_preprocessed/train
remove_crop_background('dataset/edible_telungkup', 'dataset/edible_telungkup_without_background')
# Out:
# Processing dataset/edible_telungkup\IMG_20221125_190219_731.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190219_731.png
# Processing dataset/edible_telungkup\IMG_20221125_190248_489.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190248_489.png
# Processing dataset/edible_telungkup\IMG_20221125_190322_831.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190322_831.png
# Processing dataset/edible_telungkup\IMG_20221125_190351_244.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190351_244.png
# Processing dataset/edible_telungkup\IMG_20221125_190416_160.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190416_160.png
# Processing dataset/edible_telungkup\IMG_20221125_190440_051.jpg and saving it to dataset/edible_telungkup_without_background\IMG_20221125_190440_051.png
# ...
